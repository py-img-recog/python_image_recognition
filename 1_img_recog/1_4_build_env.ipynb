# %% [markdown]
# # Pythonで学ぶ画像認識　第1章 画像認識とは？
# ## 第1.4節 画像認識のための開発環境構築

# %% [markdown]
# ### 環境構築結果の確認

# %%
import torch

print('Hello world!')

x = torch.tensor([1, 2, 3, 4])
print('CPU', x)

x = x.to('cuda')
print('GPU', x)
# Out:
# Hello world!
# CPU tensor([1, 2, 3, 4])
# GPU tensor([1, 2, 3, 4], device='cuda:0')
