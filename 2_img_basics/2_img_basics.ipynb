# %% [markdown]
# # Pythonで学ぶ画像認識
# ## 第2章「画像処理の基礎知識」

# %% [markdown]
# ### 環境構築
# * [本書のGithubリポジトリ](https://github.com/py-img-recog/python_image_recognition/)をClone
# * 下記に示す構成となっていることを確認
# ```
# My Drive
#  ├-1_img_recog
#  ├-2_img_basics
#  │  ├-gaussian_filter.py
#  │  ├-feature_extraction_conv.py
#  │  ├-feature_extraction_attention.py
#  │  ├-img_loader.py
#  │  └-2_img_basics.ipynb
#  ├-data
#  │  ├-apple.jpg
#  │  └-coffe.jpg
#  └-run.ipynb
# ```

# %% [markdown]
# * 下記コマンドでGoogleドライブをマウントしてください

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2.1 画像データを読み込んで表示してみよう
# * 下記コマンドにて画像データを読み込んで表示してください

# %%
# %run drive/MyDrive/2_img_basics/img_loader.py
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=512x512 at 0x7F19684DEFD0>
# Array size of the grayscale image: (512, 512)
# Pixel value of the grayscale image at (0, 0): 240
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7F19684DEB50>
# Array size of the color image: (512, 512, 3)
# Pixel value of the color image at (0, 0): (197, 200, 191)

# %% [markdown]
# ### 2.2 画像に平滑化フィルタをかけてみよう
# * 下記コマンドにてガウシアンフィルタを実行してください

# %%
# %run drive/MyDrive/2_img_basics/gaussian_filter.py
# Out:
# Generated kernel:
# [[0.0097565  0.02370077 0.03186045 0.02370077 0.0097565 ]
#  [0.02370077 0.0575746  0.07739634 0.0575746  0.02370077]
#  [0.03186045 0.07739634 0.10404229 0.07739634 0.03186045]
#  [0.02370077 0.0575746  0.07739634 0.0575746  0.02370077]
#  [0.0097565  0.02370077 0.03186045 0.02370077 0.0097565 ]]
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=512x512 at 0x7F19625B13D0>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F19625A6C10>

# %% [markdown]
# ### 2.3 畳み込み演算を使った特徴抽出
# * 下記コマンドにて畳み込み演算を使った特徴抽出を実行してください

# %%
# %run drive/MyDrive/2_img_basics/feature_extraction_conv.py
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F1960D31050>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F19625B1810>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F19625BB710>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F19625BBB90>

# %% [markdown]
# ### 2.4 Attentionを使った特徴抽出
# * 下記コマンドにてAttentionを使った特徴抽出を実行してください

# %%
# %run drive/MyDrive/2_img_basics/feature_extraction_attention.py
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F19625C66D0>
# <PIL.Image.Image image mode=L size=256x256 at 0x7F19625BB590>
